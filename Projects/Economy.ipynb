?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/new-india-believes-in-market-forces-will-be-the-most-preferred-investment-destination-pm-modi/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-interaction-with-pm-svanidhi-scheme-beneficiaries-of-uttar-pradesh/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-interacts-with-ceos-of-leading-oil-gas-companies/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-delivers-inaugural-address-at-4th-india-energy-forum/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-inauguration-of-india-energy-forum/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-in-the-17th-episode-of-mann-ki-baat-2-0/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-release-of-autobiography-of-dr-balasaheb-vikhe-patil/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-participates-in-abhinandan-program-in-solang/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-to-inaugurate-the-summit-responsible-ai-for-social-empowerment-2020-on-5th-oct-at-7-pm/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-inaugurates-various-six-major-projects-in-uttarakhand-to-make-river-ganga-nirmal-and-aviral/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-inauguration-of-six-mega-projects-under-namami-gange-in-uttarakhand/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/joint-statement-for-india-denmark-green-strategic-partnership/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-75th-united-nations-general-assembly-unga-session-2020/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-launches-the-age-appropriate-fitness-protocols/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-hails-passage-of-labour-reforms-bills-says-labour-reforms-will-ensure-well-being-of-workers-and-boost-economy/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-convocation-of-iit-guwahati/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-remarks-on-election-of-shri-harivansh-narayan-singh-as-deputy-chairman-of-rajya-sabha/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pm-dedicates-to-the-nation-three-key-projects-related-to-the-petroleum-sector-in-bihar/?comment=disable",
            "https://www.pmindia.gov.in/en/news_updates/pms-address-at-the-inauguration-of-three-key-projects-related-to-the-petroleum-sector-in-bihar/?comment=disable"
          ]

#the_word = input()
the_word = 'economy'

total_words = []
for url in url_list:
    r = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(r.content.lower(), 'lxml')
    words = soup.find_all(text=lambda text: text and the_word.lower() in text)
    count = len(words)
    words_list = [ ele.strip() for ele in words ]
    for word in words:
        total_words.append(word.strip())

    print('\nUrl: {}\ncontains {} of word: {}'.format(url, count, the_word))
    print(words_list)


#print(total_words)
total_count = len(total_words)
# Out:
# Url: https://www.pmindia.gov.in/en/news_updates/pm-delivers-keynote-address-at-assocham-foundation-week-2020/?comment=disable
# contains 3 of word: economy
# ...

# %%
total_count
# Out:
# 102

# %%
total_words
# Out:
# ['the prime minister said even during the pandemic, when the whole world is troubled for investment, record fdi and pfi have come to india as the world trusts the indian economy now. he gave a call for the industry to increase the domestic investment drastically in line with the increased confidence of the world.',
# ...
